# %%
include("../src/CoherentStructures.jl") #this is terrible but neccessary during development (?)
# Out:
# Main.CoherentStructures

# %%
using StreamMacros, Main.CoherentStructures
using Tensors, Arpack, JLD2, OrdinaryDiffEq
using Plots, UnicodePlots
using OrdinaryDiffEq
using DelimitedFiles
const ODE = OrdinaryDiffEq
# Out:
# OrdinaryDiffEq

# %%
JLD2.@load("Ocean_geostrophic_velocity.jld2");
UV = interpolateVF(Lon, Lat, Time, UT, VT);

# %%
# Parameters
grid_resolution        = 500
quadrature_order       = 2
nevs                   = 20
topk                   = 3
ϵ                      = 0.025
num_steps              = 20
t_initial              = minimum(Time)
t_end                  = t_initial+20     # parameter value corresponding to ϵ=0 (t_max is 90)
wind_scale             = 1e-5
wind_center            = 30;

# %%
lattitude_range = range(minimum(Lat),maximum(Lat),length=size(UT)[2]) # should be equal to Lat, but just to be safe
wind_u = repeat(collect(wind_scale.*(lattitude_range.-wind_center))',size(UT)[1],1,size(UT)[3])
wind_v = zero(VT); #no northward component of wind
wind = interpolateVF(Lon, Lat, Time, wind_u, wind_v);

# %%
# it would be much easier to write this with interp_rhs and p=UV .+ param.*wind, but that has the wrong type
interp_rhs_scaled = ODE.ODEFunction{false}((u,p,t) -> p[1](u[1],u[2],t) .+ p[3].*p[2](u[1],u[2],t))
function T(x,param)
    flow(interp_rhs_scaled, x, [t_initial, t_end]; 
        p=(UV, wind, param), tolerance=1e-10, solver=OrdinaryDiffEq.BS5())[end]
end
# Out:
# T (generic function with 1 method)

# %%
LL, UR = (-4.0, -34.0), (6.0, -28.0)
ctx, _ = regularTriangularGrid((grid_resolution, Integer(floor((UR[2] - LL[2])/(UR[1] - LL[1])*grid_resolution))), 
        LL, UR, quadrature_order = quadrature_order);
bdata = getHomDBCS(ctx, "all");

# %%
M = assembleMassMatrix(ctx, bdata=bdata);

# %%
# assemble K
DT₀(x) = linearized_transfer_function_autodiff(y -> T(y,0) , x)
A₀(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DT₀(x))))
@time K = assembleStiffnessMatrix(ctx, A₀, bdata=bdata)
nothing
# Out:
# 623.617836 seconds (169.93 M allocations: 10.138 GiB, 0.31% gc time)

# %%
evs = zeros(num_steps+1,nevs)
evs[Int(num_steps/2 +1),:] , _ = eigs(K, M, nev=20, which=:SM);

# %%
for i in 1:(num_steps/2)
    DTϵ(x) = linearized_transfer_function_autodiff(y -> T(y,i*ϵ) , x)
    Aϵ(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DTϵ(x))))
    @time Kϵ = assembleStiffnessMatrix(ctx, Aϵ, bdata=bdata)
    DTminusϵ(x) = linearized_transfer_function_autodiff(y -> T(y,-i*ϵ) , x)
    Aminusϵ(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DTminusϵ(x))))
    @time Kminusϵ = assembleStiffnessMatrix(ctx, Aminusϵ, bdata=bdata)
    evs[Int(num_steps/2 +1+i),:], _ = eigs(Kϵ, M, nev=nevs, which=:SM)
    evs[Int(num_steps/2 +1-i),:], _ = eigs(Kminusϵ, M, nev=nevs, which=:SM)
    print(Int(i), "/" ,Int(num_steps/2), "\n")
end
nothing
# Out:
# 611.222050 seconds (134.80 M allocations: 7.877 GiB, 0.14% gc time)
# 610.569500 seconds (134.57 M allocations: 7.867 GiB, 0.15% gc time)
# 1/10
# 607.285054 seconds (122.05 M allocations: 7.332 GiB, 0.17% gc time)
# 606.804043 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 2/10
# 606.896557 seconds (122.05 M allocations: 7.332 GiB, 0.17% gc time)
# 608.154201 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 3/10
# 606.692706 seconds (122.05 M allocations: 7.332 GiB, 0.17% gc time)
# 606.464433 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 4/10
# 606.501155 seconds (122.05 M allocations: 7.332 GiB, 0.14% gc time)
# 606.403495 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 5/10
# 606.641918 seconds (122.05 M allocations: 7.332 GiB, 0.11% gc time)
# 606.731632 seconds (122.05 M allocations: 7.332 GiB, 0.11% gc time)
# 6/10
# 606.290849 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 606.544845 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 7/10
# 606.841786 seconds (122.05 M allocations: 7.332 GiB, 0.11% gc time)
# 606.814545 seconds (122.05 M allocations: 7.332 GiB, 0.11% gc time)
# 8/10
# 606.941505 seconds (122.05 M allocations: 7.332 GiB, 0.17% gc time)
# 606.317715 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 9/10
# 606.379044 seconds (122.05 M allocations: 7.332 GiB, 0.14% gc time)
# 606.338229 seconds (122.05 M allocations: 7.332 GiB, 0.12% gc time)
# 10/10

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs, legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,1:topk], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,1], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,2], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,3], legend=false, fmt = :png)

# %%
[range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1)  evs]
# Out:
# 21×21 Array{Float64,2}:
#  -0.25   -3.36283  -4.53479  -8.14372  …  -27.1018  -27.9697  -27.9973
#  -0.225  -3.36298  -4.5347   -8.14249     -27.1031  -27.9718  -28.0017
#  -0.2    -3.3631   -4.53461  -8.14132     -27.1045  -27.974   -28.0062
#  -0.175  -3.36317  -4.53451  -8.14014     -27.1052  -27.9761  -28.0106
#  -0.15   -3.36314  -4.53438  -8.13883     -27.1045  -27.9782  -28.0147
#  -0.125  -3.36314  -4.53421  -8.13735  …  -27.1021  -27.9803  -28.0182
#  -0.1    -3.36311  -4.53398  -8.1356      -27.0978  -27.9823  -28.021
#  -0.075  -3.3633   -4.53369  -8.13362     -27.0914  -27.9843  -28.0229
#  -0.05   -3.3628   -4.5333   -8.13096     -27.0838  -27.9863  -28.0243
#  -0.025  -3.36231  -4.53283  -8.128       -27.0757  -27.9883  -28.0254
#   0.0    -3.36207  -4.5323   -8.12492  …  -27.0671  -27.9902  -28.0263
#   0.025  -3.36175  -4.53173  -8.12165     -27.0577  -27.9922  -28.0267
#   0.05   -3.36146  -4.53115  -8.11834     -27.048   -27.9942  -28.0268
#   0.075  -3.36118  -4.53058  -8.11506     -27.0392  -27.9964  -28.0267
#   0.1    -3.36087  -4.53001  -8.11185     -27.0313  -27.9986  -28.0265
#   0.125  -3.36064  -4.52945  -8.10883  …  -27.024   -28.0009  -28.0259
#   0.15   -3.3605   -4.52887  -8.10603     -27.0166  -28.0029  -28.0248
#   0.175  -3.36035  -4.52827  -8.10343     -27.0097  -28.0048  -28.0235
#   0.2    -3.3602   -4.52766  -8.10106     -27.0036  -28.0064  -28.0224
#   0.225  -3.36008  -4.52708  -8.09894     -26.9988  -28.0077  -28.0219
#   0.25   -3.36     -4.52653  -8.09708  …  -26.9955  -28.0089  -28.022

# %%
evs
# Out:
# 21×20 Array{Float64,2}:
#  -3.36283  -4.53479  -8.14372  -8.33566  …  -27.1018  -27.9697  -27.9973
#  -3.36298  -4.5347   -8.14249  -8.3343      -27.1031  -27.9718  -28.0017
#  -3.3631   -4.53461  -8.14132  -8.33296     -27.1045  -27.974   -28.0062
#  -3.36317  -4.53451  -8.14014  -8.33161     -27.1052  -27.9761  -28.0106
#  -3.36314  -4.53438  -8.13883  -8.33022     -27.1045  -27.9782  -28.0147
#  -3.36314  -4.53421  -8.13735  -8.3288   …  -27.1021  -27.9803  -28.0182
#  -3.36311  -4.53398  -8.1356   -8.32733     -27.0978  -27.9823  -28.021
#  -3.3633   -4.53369  -8.13362  -8.32585     -27.0914  -27.9843  -28.0229
#  -3.3628   -4.5333   -8.13096  -8.32413     -27.0838  -27.9863  -28.0243
#  -3.36231  -4.53283  -8.128    -8.32237     -27.0757  -27.9883  -28.0254
#  -3.36207  -4.5323   -8.12492  -8.32065  …  -27.0671  -27.9902  -28.0263
#  -3.36175  -4.53173  -8.12165  -8.31891     -27.0577  -27.9922  -28.0267
#  -3.36146  -4.53115  -8.11834  -8.31721     -27.048   -27.9942  -28.0268
#  -3.36118  -4.53058  -8.11506  -8.31553     -27.0392  -27.9964  -28.0267
#  -3.36087  -4.53001  -8.11185  -8.3139      -27.0313  -27.9986  -28.0265
#  -3.36064  -4.52945  -8.10883  -8.31235  …  -27.024   -28.0009  -28.0259
#  -3.3605   -4.52887  -8.10603  -8.31087     -27.0166  -28.0029  -28.0248
#  -3.36035  -4.52827  -8.10343  -8.30943     -27.0097  -28.0048  -28.0235
#  -3.3602   -4.52766  -8.10106  -8.30804     -27.0036  -28.0064  -28.0224
#  -3.36008  -4.52708  -8.09894  -8.3067      -26.9988  -28.0077  -28.0219
#  -3.36     -4.52653  -8.09708  -8.30541  …  -26.9955  -28.0089  -28.022

# %%
writedlm("D:/"*string(grid_resolution)*"_"*string(Integer(num_steps/2)*ϵ)*"_"*string(t_end-t_initial)*".csv", [range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1)  evs], ",")
