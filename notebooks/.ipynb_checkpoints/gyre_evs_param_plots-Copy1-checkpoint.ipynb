# %%
include("../src/CoherentStructures.jl") #this is terrible but neccessary during development (?)
# Out:
# Main.CoherentStructures

# %%
using StreamMacros, Main.CoherentStructures
using Tensors, Arpack, JLD2, OrdinaryDiffEq
using Plots, UnicodePlots
using OrdinaryDiffEq
using DelimitedFiles
const ODE = OrdinaryDiffEq
# Out:
# OrdinaryDiffEq

# %%
# Parameters
grid_resolution        = 300
quadrature_order       = 1
nevs                   = 20
topk                   = 3
ϵ                      = 0.005
num_steps              = 200
t₀                      = 0.5;    # parameter value corresponding to ϵ=0

# %%
rot_double_gyre = @velo_from_stream Ψ_rot_dgyre begin
    st          = heaviside(t)*heaviside(1-t)*t^2*(3-2*t) + heaviside(t-1)
    heaviside(x)= 0.5*(sign(x) + 1)
    Ψ_P         = sin(2π*x)*sin(π*y)
    Ψ_F         = sin(π*x)*sin(2π*y)
    Ψ_rot_dgyre = (1-st) * Ψ_P + st * Ψ_F
end
T(x,p) = flow(rot_double_gyre, x, [0.0, t₀ + p])[end]
# Out:
# T (generic function with 1 method)

# %%
LL, UR = (0.0, 0.0), (1.0, 1.0)
ctx, _ = regularTriangularGrid((grid_resolution, grid_resolution), LL, UR, quadrature_order = quadrature_order);

# %%
M = assembleMassMatrix(ctx);

# %%
# assemble K
DT₀(x) = linearized_transfer_function_autodiff(y -> T(y,0) , x)
A₀(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DT₀(x))))
@time K = assembleStiffnessMatrix(ctx, A₀)
nothing
# Out:
#  18.285468 seconds (68.83 M allocations: 4.173 GiB, 6.04% gc time)

# %%
evs = zeros(num_steps+1,nevs)
evs[Int(num_steps/2 +1),:] , _ = eigs(K, M, nev=20, which=:SM);

# %%
for i in 1:(num_steps/2)
    DTϵ(x) = linearized_transfer_function_autodiff(y -> T(y,i*ϵ) , x)
    Aϵ(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DTϵ(x))))
    @time Kϵ = assembleStiffnessMatrix(ctx, Aϵ)
    DTminusϵ(x) = linearized_transfer_function_autodiff(y -> T(y,-i*ϵ) , x)
    Aminusϵ(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DTminusϵ(x))))
    @time Kminusϵ = assembleStiffnessMatrix(ctx, Aminusϵ)
    evs[Int(num_steps/2 +1+i),:], _ = eigs(Kϵ, M, nev=nevs, which=:SM)
    evs[Int(num_steps/2 +1-i),:], _ = eigs(Kminusϵ, M, nev=nevs, which=:SM)
    print(Int(i), "/" ,Int(num_steps/2), "\n")
end
nothing
# Out:
#   5.452739 seconds (29.96 M allocations: 1.835 GiB, 7.11% gc time)
#   5.341026 seconds (29.95 M allocations: 1.834 GiB, 4.88% gc time)
# 1/100
#   3.165809 seconds (23.96 M allocations: 1.545 GiB, 4.69% gc time)
#   3.022050 seconds (23.96 M allocations: 1.545 GiB, 5.77% gc time)
# 2/100
#   3.259587 seconds (23.96 M allocations: 1.545 GiB, 9.20% gc time)
#   2.865045 seconds (23.96 M allocations: 1.545 GiB, 5.53% gc time)
# 3/100
#   3.117398 seconds (23.96 M allocations: 1.545 GiB, 4.43% gc time)
#   2.972001 seconds (23.96 M allocations: 1.545 GiB, 5.78% gc time)
# 4/100
#   3.174133 seconds (23.96 M allocations: 1.545 GiB, 4.41% gc time)
#   2.937616 seconds (23.96 M allocations: 1.545 GiB, 5.33% gc time)
# 5/100
#   3.209990 seconds (23.96 M allocations: 1.545 GiB, 4.77% gc time)
#   3.227068 seconds (23.96 M allocations: 1.545 GiB, 14.83% gc time)
# 6/100
#   3.469186 seconds (23.96 M allocations: 1.545 GiB, 13.50% gc time)
#   2.795030 seconds (23.96 M allocations: 1.545 GiB, 5.68% gc time)
# 7/100
#   3.415601 seconds (23.96 M allocations: 1.545 GiB, 13.04% gc time)
#   2.791240 seconds (23.96 M allocations: 1.545 GiB, 5.60% gc time)
# 8/100
#   3.463602 seconds (23.96 M allocations: 1.545 GiB, 14.08% gc time)
#   2.782748 seconds (23.96 M allocations: 1.545 GiB, 5.64% gc time)
# 9/100
#   3.425496 seconds (23.96 M allocations: 1.545 GiB, 12.95% gc time)
#   2.761776 seconds (23.96 M allocations: 1.545 GiB, 5.72% gc time)
# 10/100
#   3.434933 seconds (23.96 M allocations: 1.545 GiB, 12.99% gc time)
#   2.751525 seconds (23.96 M allocations: 1.545 GiB, 5.68% gc time)
# 11/100
#   3.488868 seconds (23.96 M allocations: 1.545 GiB, 13.93% gc time)
#   2.732962 seconds (23.96 M allocations: 1.545 GiB, 5.70% gc time)
# 12/100
#   3.459508 seconds (23.96 M allocations: 1.545 GiB, 12.87% gc time)
#   2.741446 seconds (23.96 M allocations: 1.545 GiB, 5.79% gc time)
# 13/100
#   3.475703 seconds (23.96 M allocations: 1.545 GiB, 13.00% gc time)
#   2.727665 seconds (23.96 M allocations: 1.545 GiB, 5.83% gc time)
# 14/100
#   3.483923 seconds (23.96 M allocations: 1.545 GiB, 12.69% gc time)
#   2.718492 seconds (23.96 M allocations: 1.545 GiB, 5.77% gc time)
# 15/100
#   3.495557 seconds (23.96 M allocations: 1.545 GiB, 12.69% gc time)
#   2.704014 seconds (23.96 M allocations: 1.545 GiB, 5.81% gc time)
# 16/100
#   3.513172 seconds (23.96 M allocations: 1.545 GiB, 12.70% gc time)
#   2.698423 seconds (23.96 M allocations: 1.545 GiB, 5.88% gc time)
# 17/100
#   3.523628 seconds (23.96 M allocations: 1.545 GiB, 12.82% gc time)
#   2.687710 seconds (23.96 M allocations: 1.545 GiB, 5.89% gc time)
# 18/100
#   3.528967 seconds (23.96 M allocations: 1.545 GiB, 12.58% gc time)
#   2.673475 seconds (23.96 M allocations: 1.545 GiB, 5.87% gc time)
# 19/100
#   3.577497 seconds (23.96 M allocations: 1.545 GiB, 12.67% gc time)
#   2.677500 seconds (23.96 M allocations: 1.545 GiB, 5.86% gc time)
# 20/100
#   3.545588 seconds (23.96 M allocations: 1.545 GiB, 12.49% gc time)
#   2.647680 seconds (23.96 M allocations: 1.545 GiB, 5.92% gc time)
# 21/100
#   3.618774 seconds (23.96 M allocations: 1.545 GiB, 13.52% gc time)
#   2.642589 seconds (23.96 M allocations: 1.545 GiB, 5.84% gc time)
# 22/100
#   3.561228 seconds (23.96 M allocations: 1.545 GiB, 12.40% gc time)
#   2.635994 seconds (23.96 M allocations: 1.545 GiB, 6.00% gc time)
# 23/100
#   3.590310 seconds (23.96 M allocations: 1.545 GiB, 12.34% gc time)
#   2.632713 seconds (23.96 M allocations: 1.545 GiB, 5.95% gc time)
# 24/100
#   3.603681 seconds (23.96 M allocations: 1.545 GiB, 12.44% gc time)
#   2.622310 seconds (23.96 M allocations: 1.545 GiB, 6.02% gc time)
# 25/100
#   3.577198 seconds (23.96 M allocations: 1.545 GiB, 12.36% gc time)
#   2.592268 seconds (23.96 M allocations: 1.545 GiB, 6.09% gc time)
# 26/100
#   3.607239 seconds (23.96 M allocations: 1.545 GiB, 12.50% gc time)
#   2.585872 seconds (23.96 M allocations: 1.545 GiB, 6.36% gc time)
# 27/100
#   3.667961 seconds (23.96 M allocations: 1.545 GiB, 13.34% gc time)
#   2.560934 seconds (23.96 M allocations: 1.545 GiB, 6.06% gc time)
# 28/100
#   3.627521 seconds (23.96 M allocations: 1.545 GiB, 12.34% gc time)
#   2.562338 seconds (23.96 M allocations: 1.545 GiB, 6.14% gc time)
# 29/100
#   3.699012 seconds (23.96 M allocations: 1.545 GiB, 12.88% gc time)
#   2.572640 seconds (23.96 M allocations: 1.545 GiB, 6.03% gc time)
# 30/100
#   3.657012 seconds (23.96 M allocations: 1.545 GiB, 12.39% gc time)
#   2.544629 seconds (23.96 M allocations: 1.545 GiB, 6.11% gc time)
# 31/100
#   3.641010 seconds (23.96 M allocations: 1.545 GiB, 12.06% gc time)
#   2.547143 seconds (23.96 M allocations: 1.545 GiB, 6.14% gc time)
# 32/100
#   3.735886 seconds (23.96 M allocations: 1.545 GiB, 12.16% gc time)
#   2.586243 seconds (23.96 M allocations: 1.545 GiB, 6.25% gc time)
# 33/100
#   3.993844 seconds (23.96 M allocations: 1.545 GiB, 14.22% gc time)
#   2.583102 seconds (23.96 M allocations: 1.545 GiB, 6.40% gc time)
# 34/100
#   3.796574 seconds (23.96 M allocations: 1.545 GiB, 12.26% gc time)
#   2.562287 seconds (23.96 M allocations: 1.545 GiB, 6.26% gc time)
# 35/100
#   3.838145 seconds (23.96 M allocations: 1.545 GiB, 12.76% gc time)
#   2.535004 seconds (23.96 M allocations: 1.545 GiB, 6.30% gc time)
# 36/100
#   3.781284 seconds (23.96 M allocations: 1.545 GiB, 12.45% gc time)
#   2.519268 seconds (23.96 M allocations: 1.545 GiB, 6.19% gc time)
# 37/100
#   3.769145 seconds (23.96 M allocations: 1.545 GiB, 11.97% gc time)
#   2.515320 seconds (23.96 M allocations: 1.545 GiB, 6.40% gc time)
# 38/100
#   3.810577 seconds (23.96 M allocations: 1.545 GiB, 11.94% gc time)
#   2.495038 seconds (23.96 M allocations: 1.545 GiB, 6.32% gc time)
# 39/100
#   3.875688 seconds (23.96 M allocations: 1.545 GiB, 12.63% gc time)
#   2.495877 seconds (23.96 M allocations: 1.545 GiB, 6.53% gc time)
# 40/100
#   3.900635 seconds (23.96 M allocations: 1.545 GiB, 12.94% gc time)
#   2.469691 seconds (23.96 M allocations: 1.545 GiB, 6.45% gc time)
# 41/100
#   3.864019 seconds (23.96 M allocations: 1.545 GiB, 12.83% gc time)
#   2.443663 seconds (23.96 M allocations: 1.545 GiB, 6.41% gc time)
# 42/100
#   3.796618 seconds (23.96 M allocations: 1.545 GiB, 11.73% gc time)
#   2.437640 seconds (23.96 M allocations: 1.545 GiB, 6.53% gc time)
# 43/100
#   3.876825 seconds (23.96 M allocations: 1.545 GiB, 12.57% gc time)
#   2.428372 seconds (23.96 M allocations: 1.545 GiB, 6.51% gc time)
# 44/100
#   3.881519 seconds (23.96 M allocations: 1.545 GiB, 12.52% gc time)
#   2.414491 seconds (23.96 M allocations: 1.545 GiB, 6.46% gc time)
# 45/100
#   3.910961 seconds (23.96 M allocations: 1.545 GiB, 12.71% gc time)
#   2.412715 seconds (23.96 M allocations: 1.545 GiB, 6.42% gc time)
# 46/100
#   3.944492 seconds (23.96 M allocations: 1.545 GiB, 12.46% gc time)
#   2.420996 seconds (23.96 M allocations: 1.545 GiB, 6.52% gc time)
# 47/100
#   3.926258 seconds (23.96 M allocations: 1.545 GiB, 12.33% gc time)
#   2.384988 seconds (23.96 M allocations: 1.545 GiB, 6.64% gc time)
# 48/100
#   3.869560 seconds (23.96 M allocations: 1.545 GiB, 11.54% gc time)
#   2.377896 seconds (23.96 M allocations: 1.545 GiB, 6.64% gc time)
# 49/100
#   3.883434 seconds (23.96 M allocations: 1.545 GiB, 11.57% gc time)
#   2.358581 seconds (23.96 M allocations: 1.545 GiB, 6.75% gc time)
# 50/100
#   3.972400 seconds (23.96 M allocations: 1.545 GiB, 12.29% gc time)
#   2.352969 seconds (23.96 M allocations: 1.545 GiB, 6.73% gc time)
# 51/100
#   3.908956 seconds (23.96 M allocations: 1.545 GiB, 11.58% gc time)
#   2.322118 seconds (23.96 M allocations: 1.545 GiB, 6.89% gc time)
# 52/100
#   3.915009 seconds (23.96 M allocations: 1.545 GiB, 11.44% gc time)
#   2.298935 seconds (23.96 M allocations: 1.545 GiB, 6.93% gc time)
# 53/100
#   3.928729 seconds (23.96 M allocations: 1.545 GiB, 11.54% gc time)
#   2.274011 seconds (23.96 M allocations: 1.545 GiB, 6.96% gc time)
# 54/100
#   3.931985 seconds (23.96 M allocations: 1.545 GiB, 11.32% gc time)
#   2.270886 seconds (23.96 M allocations: 1.545 GiB, 7.05% gc time)
# 55/100
#   3.943908 seconds (23.96 M allocations: 1.545 GiB, 11.61% gc time)
#   2.252577 seconds (23.96 M allocations: 1.545 GiB, 6.93% gc time)
# 56/100
#   3.955485 seconds (23.96 M allocations: 1.545 GiB, 11.19% gc time)
#   2.265695 seconds (23.96 M allocations: 1.545 GiB, 7.17% gc time)
# 57/100
#   3.966135 seconds (23.96 M allocations: 1.545 GiB, 11.35% gc time)
#   2.260586 seconds (23.96 M allocations: 1.545 GiB, 7.10% gc time)
# 58/100
#   3.976951 seconds (23.96 M allocations: 1.545 GiB, 11.31% gc time)
#   2.253535 seconds (23.96 M allocations: 1.545 GiB, 7.03% gc time)
# 59/100
#   3.975551 seconds (23.96 M allocations: 1.545 GiB, 11.21% gc time)
#   2.229529 seconds (23.96 M allocations: 1.545 GiB, 7.12% gc time)
# 60/100
#   3.963052 seconds (23.96 M allocations: 1.545 GiB, 11.44% gc time)
#   2.234155 seconds (23.96 M allocations: 1.545 GiB, 7.55% gc time)
# 61/100
#   4.039089 seconds (23.96 M allocations: 1.545 GiB, 12.06% gc time)
#   2.229236 seconds (23.96 M allocations: 1.545 GiB, 7.55% gc time)
# 62/100
#   4.055649 seconds (23.96 M allocations: 1.545 GiB, 11.77% gc time)
#   2.194123 seconds (23.96 M allocations: 1.545 GiB, 7.69% gc time)
# 63/100
#   4.098982 seconds (23.96 M allocations: 1.545 GiB, 12.50% gc time)
#   2.181339 seconds (23.96 M allocations: 1.545 GiB, 7.61% gc time)
# 64/100
#   4.072516 seconds (23.96 M allocations: 1.545 GiB, 11.66% gc time)
#   2.138567 seconds (23.96 M allocations: 1.545 GiB, 7.72% gc time)
# 65/100
#   4.091504 seconds (23.96 M allocations: 1.545 GiB, 11.72% gc time)
#   2.136793 seconds (23.96 M allocations: 1.545 GiB, 7.98% gc time)
# 66/100
#   4.106502 seconds (23.96 M allocations: 1.545 GiB, 11.40% gc time)
#   2.180560 seconds (23.96 M allocations: 1.545 GiB, 8.45% gc time)
# 67/100
#   4.030339 seconds (23.96 M allocations: 1.545 GiB, 11.05% gc time)
#   2.077129 seconds (23.96 M allocations: 1.545 GiB, 7.73% gc time)
# 68/100
#   4.056665 seconds (23.96 M allocations: 1.545 GiB, 10.91% gc time)
#   2.078268 seconds (23.96 M allocations: 1.545 GiB, 7.61% gc time)
# 69/100
#   4.053312 seconds (23.96 M allocations: 1.545 GiB, 11.04% gc time)
#   2.068065 seconds (23.96 M allocations: 1.545 GiB, 7.67% gc time)
# 70/100
#   4.156618 seconds (23.96 M allocations: 1.545 GiB, 11.68% gc time)
#   2.065582 seconds (23.96 M allocations: 1.545 GiB, 7.51% gc time)
# 71/100
#   4.125590 seconds (23.96 M allocations: 1.545 GiB, 11.59% gc time)
#   2.048117 seconds (23.96 M allocations: 1.545 GiB, 7.64% gc time)
# 72/100
#   4.137924 seconds (23.96 M allocations: 1.545 GiB, 11.62% gc time)
#   2.015152 seconds (23.96 M allocations: 1.545 GiB, 7.71% gc time)
# 73/100
#   4.164555 seconds (23.96 M allocations: 1.545 GiB, 11.69% gc time)
#   1.976595 seconds (23.96 M allocations: 1.545 GiB, 7.82% gc time)
# 74/100
#   4.160728 seconds (23.96 M allocations: 1.545 GiB, 11.50% gc time)
#   1.935865 seconds (23.96 M allocations: 1.545 GiB, 8.16% gc time)
# 75/100
#   4.167730 seconds (23.96 M allocations: 1.545 GiB, 11.60% gc time)
#   1.913486 seconds (23.96 M allocations: 1.545 GiB, 8.24% gc time)
# 76/100
#   4.174576 seconds (23.96 M allocations: 1.545 GiB, 11.55% gc time)
#   1.910331 seconds (23.96 M allocations: 1.545 GiB, 8.25% gc time)
# 77/100
#   4.181588 seconds (23.96 M allocations: 1.545 GiB, 11.47% gc time)
#   1.929369 seconds (23.96 M allocations: 1.545 GiB, 8.16% gc time)
# 78/100
#   4.196719 seconds (23.96 M allocations: 1.545 GiB, 11.53% gc time)
#   1.910913 seconds (23.96 M allocations: 1.545 GiB, 8.24% gc time)
# 79/100
#   4.220701 seconds (23.96 M allocations: 1.545 GiB, 11.40% gc time)
#   1.914800 seconds (23.96 M allocations: 1.545 GiB, 8.17% gc time)
# 80/100
#   4.214418 seconds (23.96 M allocations: 1.545 GiB, 11.42% gc time)
#   1.910331 seconds (23.96 M allocations: 1.545 GiB, 8.12% gc time)
# 81/100
#   4.228170 seconds (23.96 M allocations: 1.545 GiB, 11.28% gc time)
#   1.909806 seconds (23.96 M allocations: 1.545 GiB, 8.43% gc time)
# 82/100
#   4.313283 seconds (23.96 M allocations: 1.545 GiB, 12.13% gc time)
#   1.884005 seconds (23.96 M allocations: 1.545 GiB, 8.26% gc time)
# 83/100
#   4.257839 seconds (23.96 M allocations: 1.545 GiB, 11.31% gc time)
#   1.822163 seconds (23.96 M allocations: 1.545 GiB, 8.58% gc time)
# 84/100
#   4.269507 seconds (23.96 M allocations: 1.545 GiB, 11.29% gc time)
#   1.759464 seconds (23.96 M allocations: 1.545 GiB, 8.79% gc time)
# 85/100
#   4.273702 seconds (23.96 M allocations: 1.545 GiB, 11.18% gc time)
#   1.751989 seconds (23.96 M allocations: 1.545 GiB, 8.94% gc time)
# 86/100
#   4.260934 seconds (23.96 M allocations: 1.545 GiB, 10.47% gc time)
#   1.783169 seconds (23.96 M allocations: 1.545 GiB, 8.91% gc time)
# 87/100
#   4.320135 seconds (23.96 M allocations: 1.545 GiB, 10.38% gc time)
#   1.802298 seconds (23.96 M allocations: 1.545 GiB, 8.91% gc time)
# 88/100
#   4.365361 seconds (23.96 M allocations: 1.545 GiB, 10.66% gc time)
#   1.805462 seconds (23.96 M allocations: 1.545 GiB, 8.76% gc time)
# 89/100
#   4.327751 seconds (23.96 M allocations: 1.545 GiB, 10.35% gc time)
#   1.785692 seconds (23.96 M allocations: 1.545 GiB, 9.00% gc time)
# 90/100
#   4.392222 seconds (23.96 M allocations: 1.545 GiB, 11.04% gc time)
#   1.757161 seconds (23.96 M allocations: 1.545 GiB, 8.77% gc time)
# 91/100
#   4.479615 seconds (23.96 M allocations: 1.545 GiB, 11.25% gc time)
#   1.695631 seconds (23.96 M allocations: 1.545 GiB, 10.14% gc time)
# 92/100
#   4.463008 seconds (23.96 M allocations: 1.545 GiB, 10.95% gc time)
#   1.621877 seconds (23.96 M allocations: 1.545 GiB, 9.54% gc time)
# 93/100
#   4.419863 seconds (23.96 M allocations: 1.545 GiB, 10.95% gc time)
#   1.633606 seconds (23.96 M allocations: 1.545 GiB, 9.49% gc time)
# 94/100
#   4.424868 seconds (23.96 M allocations: 1.545 GiB, 11.04% gc time)
#   1.655952 seconds (23.96 M allocations: 1.545 GiB, 9.60% gc time)
# 95/100
#   4.444153 seconds (23.96 M allocations: 1.545 GiB, 10.96% gc time)
#   1.640422 seconds (23.96 M allocations: 1.545 GiB, 9.66% gc time)
# 96/100
#   4.451330 seconds (23.96 M allocations: 1.545 GiB, 11.06% gc time)
#   1.646928 seconds (23.96 M allocations: 1.545 GiB, 9.91% gc time)
# 97/100
#   4.556652 seconds (23.96 M allocations: 1.545 GiB, 11.27% gc time)
#   1.688264 seconds (23.96 M allocations: 1.545 GiB, 9.68% gc time)
# 98/100
#   4.573532 seconds (23.96 M allocations: 1.545 GiB, 10.47% gc time)
#   1.653990 seconds (23.96 M allocations: 1.545 GiB, 9.68% gc time)
# 99/100
#   4.521638 seconds (23.96 M allocations: 1.545 GiB, 10.78% gc time)
#   1.459782 seconds (23.96 M allocations: 1.545 GiB, 11.01% gc time)
# 100/100

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs, legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,1:topk], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,1], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,2], legend=false, fmt = :png)

# %%
Plots.plot(range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1), evs[:,3], legend=false, fmt = :png)

# %%
[range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1)  evs]
# Out:
# 201×21 Array{Float64,2}:
#  -0.5     3.4529e-12    -9.86973  …   -167.829   -167.831   -177.717
#  -0.495  -1.27104e-12   -9.87726      -168.217   -168.318   -178.055
#  -0.49   -6.58917e-13   -9.89968      -169.375   -169.778   -179.066
#  -0.485  -8.02747e-13   -9.93676      -171.288   -172.195   -180.742
#  -0.48   -9.38527e-13   -9.98812      -173.931   -175.543   -183.072
#  -0.475  -9.16267e-13  -10.0533   …   -177.264   -179.783   -186.046
#  -0.47   -1.63397e-12  -10.1317       -181.229   -184.863   -189.661
#  -0.465  -1.04994e-12  -10.223        -185.747   -190.711   -193.918
#  -0.46   -1.56164e-12  -10.3267       -190.714   -197.229   -198.834
#  -0.455  -1.37501e-12  -10.4426       -196.006   -204.257   -204.436
#  -0.45   -1.89465e-12  -10.5705   …   -201.486   -210.763   -211.457
#  -0.445  -1.71435e-12  -10.7105       -207.017   -217.792   -217.873
#  -0.44   -2.55385e-12  -10.8627       -214.687   -220.349   -225.83
#   ⋮                               ⋱                            ⋮
#   0.445   2.77194e-7   -69.4795      -1153.46   -1210.44   -1292.24
#   0.45   -4.31891e-9   -69.5855   …  -1157.91   -1228.57   -1307.95
#   0.455   8.0309e-8    -69.6541      -1164.46   -1247.34   -1323.89
#   0.46    4.24581e-7   -69.684       -1171.73   -1266.45   -1339.14
#   0.465  -3.75428e-7   -69.6741      -1179.2    -1285.69   -1353.74
#   0.47    6.59153e-8   -69.6232      -1186.61   -1304.98   -1368.78
#   0.475  -3.8672e-7    -69.5302   …  -1193.82   -1324.35   -1384.07
#   0.48    2.06338e-7   -69.3935      -1200.66   -1343.98   -1391.2
#   0.485   1.01443e-7   -69.2115      -1206.91   -1363.94   -1395.44
#   0.49   -2.43451e-7   -68.9822      -1212.37   -1384.1    -1400.98
#   0.495  -6.18342e-7   -68.7049      -1216.89   -1403.01   -1409.2
#   0.5    -3.94467e-8   -68.3813   …  -1220.39   -1414.3    -1425.8

# %%
evs
# Out:
# 201×20 Array{Float64,2}:
#   3.4529e-12    -9.86973    -9.86978  …   -167.829   -167.831   -177.717
#  -1.27104e-12   -9.87726    -9.90879      -168.217   -168.318   -178.055
#  -6.58917e-13   -9.89968   -10.0256       -169.375   -169.778   -179.066
#  -8.02747e-13   -9.93676   -10.2192       -171.288   -172.195   -180.742
#  -9.38527e-13   -9.98812   -10.4882       -173.931   -175.543   -183.072
#  -9.16267e-13  -10.0533    -10.8306   …   -177.264   -179.783   -186.046
#  -1.63397e-12  -10.1317    -11.2443       -181.229   -184.863   -189.661
#  -1.04994e-12  -10.223     -11.7266       -185.747   -190.711   -193.918
#  -1.56164e-12  -10.3267    -12.2751       -190.714   -197.229   -198.834
#  -1.37501e-12  -10.4426    -12.8869       -196.006   -204.257   -204.436
#  -1.89465e-12  -10.5705    -13.5597   …   -201.486   -210.763   -211.457
#  -1.71435e-12  -10.7105    -14.2907       -207.017   -217.792   -217.873
#  -2.55385e-12  -10.8627    -15.0775       -214.687   -220.349   -225.83
#   ⋮                                   ⋱
#   2.77194e-7   -69.4795   -126.959       -1153.46   -1210.44   -1292.24
#  -4.31891e-9   -69.5855   -127.021    …  -1157.91   -1228.57   -1307.95
#   8.0309e-8    -69.6541   -127.074       -1164.46   -1247.34   -1323.89
#   4.24581e-7   -69.684    -127.119       -1171.73   -1266.45   -1339.14
#  -3.75428e-7   -69.6741   -127.156       -1179.2    -1285.69   -1353.74
#   6.59153e-8   -69.6232   -127.186       -1186.61   -1304.98   -1368.78
#  -3.8672e-7    -69.5302   -127.209    …  -1193.82   -1324.35   -1384.07
#   2.06338e-7   -69.3935   -127.226       -1200.66   -1343.98   -1391.2
#   1.01443e-7   -69.2115   -127.238       -1206.91   -1363.94   -1395.44
#  -2.43451e-7   -68.9822   -127.246       -1212.37   -1384.1    -1400.98
#  -6.18342e-7   -68.7049   -127.249       -1216.89   -1403.01   -1409.2
#  -3.94467e-8   -68.3813   -127.25     …  -1220.39   -1414.3    -1425.8

# %%
writedlm("D:/"*string(grid_resolution)*"_"*string(Integer(num_steps/2)*ϵ)*".csv", [range(-(num_steps/2)*ϵ,(num_steps/2)*ϵ,length=num_steps+1)  evs], ",")
