# %%
include("../../src/CoherentStructures.jl") #this is terrible but neccessary during development (?)
# Out:
# Main.CoherentStructures

# %%
using StreamMacros, Main.CoherentStructures
using Tensors, Arpack, Distances
using Plots

# %%
# Parameters
grid_resolution        = 100
quadrature_order       = 2
selected_ev            = 2;      # which Eigenvector to choose
ϵ                      = 0.5     # perturbation
a                      = 0.98;   # parameter value corresponding to ϵ=0

# %%
T(x ,p) = [rem2pi(x[1] + x[2] + (a+p)*sin(x[1]), RoundDown),
           rem2pi(       x[2] + (a+p)*sin(x[1]), RoundDown)]
# Out:
# T (generic function with 1 method)

# %%
using Random

# %%
LL, UR = (0.0, 0.0), (2π, 2π)
ctx, _ = regularTriangularGrid((grid_resolution, grid_resolution), LL, UR, quadrature_order = quadrature_order)
pred(x,y) = peuclidean(x, y, [2π, 2π]) < 1e-9
bdata = BoundaryData(ctx, pred);

# %%
M = assembleMassMatrix(ctx, bdata=bdata);

# %%
DT₀(x) = linearized_flow_autodiff(y -> T(y,0) , x)
A₀(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DT₀(x))))
@time K = assembleStiffnessMatrix(ctx, A₀, bdata=bdata);
# Out:
#   2.740816 seconds (20.86 M allocations: 766.317 MiB, 6.50% gc time)

# %%
# solve the linear system
@time λ₀, u₀ = eigs(K, M, which=:SM)
@assert all(imag.(u₀) .== 0)
@assert all(imag.(λ₀) .== 0)
u₀ = real.(u₀[:,selected_ev])
λ₀ = real.(λ₀[selected_ev])
u₀ = u₀ ./ sqrt(u₀'*M*u₀)        # L2 normalization
if u₀[Int(floor(0.5*grid_resolution*grid_resolution+0.5*grid_resolution))]<0
    u₀ = -u₀
end
λ₀
# Out:
#   3.036991 seconds (9.51 M allocations: 553.516 MiB, 4.57% gc time)
# -1.1044142544053228

# %%
# assemble the linear response matrix L
Adot = x -> linear_response_tensor(T, x, 0)
@time L = assembleStiffnessMatrix(ctx, Adot, bdata=bdata);
# Out:
#   3.268681 seconds (28.52 M allocations: 1.332 GiB, 7.58% gc time)

# %%
# solve the system for the derivative u_dot
lhs = [K-λ₀*M   -M*u₀
        u₀'*M      0]
rhs = [-L*u₀    ;  0]

@time b = lhs \ rhs
u_dot = b[1:end-1]
λ_dot = b[end]
# Out:
#   0.668816 seconds (2.45 M allocations: 141.423 MiB, 3.90% gc time)
# -0.22433953045038185

# %%
# calculate the exact uϵ
DTϵ(x) = linearized_flow_autodiff(y -> T(y,ϵ) , x)
Aϵ(x) = 0.5*(one(Tensor{2,2}) + dott(inv(DTϵ(x))))
Kϵ = assembleStiffnessMatrix(ctx, Aϵ, bdata=bdata)
λϵ, uϵ = eigs(Kϵ, M, which=:SM)
@assert all(imag.(uϵ) .== 0)
@assert all(imag.(λϵ) .== 0)
uϵ = real.(uϵ[:,selected_ev])
λϵ = real.(λϵ[selected_ev])
uϵ = uϵ ./ sqrt(uϵ'*M*uϵ)
if uϵ[Int(floor(0.5*grid_resolution*grid_resolution+0.5*grid_resolution))]<0
    uϵ = -uϵ
end
λϵ
# Out:
# -1.2508052009050472

# %%
λ₀ + ϵ*λ_dot
# Out:
# -1.2165840196305138

# %%
color =    :balance
xticks =   0:2:6
yticks =   0:2:6
colorbar = :left
cmin =     -0.3
cmax =     0.3
cmin_lr =  -0.2
cmax_lr =  0.2
#unfortunately there is no option for colorbar ticks


original      = plot_u(ctx, u₀,  grid_resolution, grid_resolution, title="u₀", bdata=bdata,
                colorbar=colorbar, color=color, clims=(cmin,cmax), xticks=xticks, yticks=yticks)
derivative    = plot_u(ctx, u_dot,       grid_resolution, grid_resolution, title="u̇ ₀", bdata=bdata,
                colorbar=colorbar, color=color, clims=(cmin_lr,cmax_lr), xticks=xticks, yticks=yticks)
extrapolated  = plot_u(ctx, u₀ + ϵ*u_dot, grid_resolution, grid_resolution, title="u₀ + $(ϵ)u̇ ₀", bdata=bdata,
                colorbar=colorbar, color=color, clims=(cmin,cmax), xticks=xticks, yticks=yticks)
exact         = plot_u(ctx, uϵ,          grid_resolution, grid_resolution, title="uϵ", bdata=bdata,
                colorbar=colorbar, color=color, clims=(cmin,cmax), xticks=xticks, yticks=yticks)
Plots.plot(original,derivative,extrapolated,exact, fmt=:png, dpi=500)

# %%
using StaticArrays
using Contour

# %%
#only works for 2D
function apply2curve(flowmap, curve::Curve2{T}) where {T}
    moved_points = [SVector{2,Float64}(flowmap(x)) for x in zip(coordinates(curve)...)]
    return Curve2(moved_points)   
end
# Out:
# apply2curve (generic function with 1 method)

# %%
function getLength(curve, tensorfield=(x,y) -> 1)
    xs, ys = coordinates(curve)
    n = length(xs)
    result = 0
    for j in 1:(n-1)
        current_x, current_y   = xs[j], ys[j]
        next_x, next_y         = xs[j+1], ys[j+1]
        approxTangentVector = [next_x - current_x, next_y - current_y]
        result += sqrt(approxTangentVector ⋅ (tensorfield(curx, cury) * approxTangentVector))
    end
    return result
end
# Out:
# getLength (generic function with 2 methods)

# %%
# from contour.jl we only get the guarantee that either the first and last points are equal, or the contour starts and
# ends at the boundary of Ω. in the last case, we will have to construct a closed curve e.g. in order to determine the
# enclosed area
function closeCurve(ctx,curve::Curve2{T};tolerance=0.0,orientation=:clockwise) where {T}
    xs, ys = coordinates(curve)
    start_x, start_y, end_x, end_y = xs[1], ys[1], xs[end], ys[end]
    
    if (start_x == end_x && start_y == end_y)
        return curve
    end  
    
    points = [SA[x,y] for (x,y) in zip(xs,ys)]

    LL, UR = ctx.spatialBounds
    #Curve2 wants StaticArrays
    LL, UR = SA[LL[1], LL[2]], SA[UR[1], UR[2]]
    LR, UL = SA[UR[1], LL[2]], SA[LL[1], UR[2]] 
    
    # We have a rectangle, and order its sides like
    #     3                         3
    #    --                        --
    #  2|  |4  for clockwise,    4|  |2 for anticlockwise orientation.
    #    --                        --
    #     1                         1
    #
    # corners[i] then is the next corner in the respective orientation.
    
    if orientation==:clockwise
        corners = [LL, UL, UR, LR]
    elseif orientation ==:anticlockwise
        corners = [LR, UR, UL, LL]
    else
        error("Unknown orientation '",orientation,"'!")
    end
    
    if     abs(end_y-corners[1][2])<=tolerance
        side = 1
    elseif abs(end_x-corners[2][1])<=tolerance
        side = 2
    elseif abs(end_y-corners[3][2])<=tolerance
        side = 3
    elseif abs(end_x-corners[4][1])<=tolerance
        side = 4
    else                              # point does not lie on the boundary
        error("A curve has either to be closed or start and end at the boundary!")
    end
    
    i = 0
    while(abs(start_x-end_x)>tolerance && abs(start_y-end_y)>tolerance)
        push!(points,corners[side])
        end_x = corners[side][1]
        end_y = corners[side][2]
        side = (side%4)+1
        i += 1
        if i>4  # might happen if the first point is not on the border, prevent infinite loops
            error("A curve has either to be closed or start and end at the boundary!")
        end
    end
    push!(points,points[1])  # close curve
    return Curve2(points)
end
# Out:
# closeCurve (generic function with 1 method)

# %%
# If the first point is not the last point, we might get vol(Ω)-area instead
function getEuclideanArea(ctx,curve;tolerance=0.0)
    
    curve = closeCurve(ctx,curve,tolerance=tolerance)
        
    xs, ys = coordinates(curve)
    center_x, center_y = mean(xs), mean(ys)
    n = length(xs)
    result = 0.0
    for j in 1:(n-1)
        current_x, current_y   = xs[j], ys[j]
        next_x, next_y         = xs[j+1], ys[j+1]

        x1 = current_x - center_x
        x2 = next_x - center_x
        y1 = current_y - center_y
        y2 = next_y - center_y
        
        area = 0.5*det([x2 y2; x1 y1])
        result +=area
    end
    return abs(result)
end
# Out:
# getEuclideanArea (generic function with 1 method)

# %%
function dynamic_cheeger_value(ctx, curve, flowmap; tolerance=0.0)
    LL, UR = ctx.spatialBounds
    volume_Ω = (UR[1] - LL[1]) * (UR[2] - LL[2])
    curve_closed_cw  = closeCurve(ctx,curve,tolerance=tolerance,orientation=:clockwise)
    image_curve_cw   = apply2curve(flowmap,curve_closed_cw)
    curve_closed_acw = closeCurve(ctx,curve,tolerance=tolerance,orientation=:anticlockwise)
    image_curve_acw  = apply2curve(flowmap,curve_closed_acw)
    combined_length  = min(getLength(curve_closed_cw)  + getLength(image_curve_cw),
                           getLength(curve_closed_acw) + getLength(image_curve_acw))
    volume_curve = getEuclideanArea(ctx,curve,tolerance=tolerance)
    return 0.5 * combined_length / min(volume_curve, (volume_Ω - volume_curve))
end
# Out:
# dynamic_cheeger_value (generic function with 1 method)

# %%
function get_levelset(ctx, u, c;
        x_resolution=nothing, y_resolution=nothing, n_candidates=10, bdata=BoundaryData())
    
    if x_resolution==nothing
        x_resolution = ctx.numberOfPointsInEachDirection[1]
    end
    if y_resolution==nothing
        y_resolution = ctx.numberOfPointsInEachDirection[2]
    end
    
    xs = range(ctx.spatialBounds[1][1], stop=ctx.spatialBounds[2][1], length=x_resolution)
    ys = range(ctx.spatialBounds[1][2], stop=ctx.spatialBounds[2][2], length=y_resolution)
    u_dofvals = undoBCS(ctx, u, bdata)
    u_nodevals = u_dofvals[ctx.node_to_dof]

    fs = [evaluate_function_from_node_or_cellvals(ctx, u_nodevals, Vec{2}((x,y)))
        for x in xs, y in ys]
    
    return Contour.contour(xs,ys,fs,c)
    
end
# Out:
# get_levelset (generic function with 1 method)

# %%
function get_minimal_levelset(ctx, u, objective_function; 
        x_resolution=nothing, y_resolution=nothing, n_candidates=100, bdata=BoundaryData())
    
    if x_resolution==nothing
        x_resolution = ctx.numberOfPointsInEachDirection[1]
    end
    if y_resolution==nothing
        y_resolution = ctx.numberOfPointsInEachDirection[2]
    end
    
    xs = range(ctx.spatialBounds[1][1], stop=ctx.spatialBounds[2][1], length=x_resolution)
    ys = range(ctx.spatialBounds[1][2], stop=ctx.spatialBounds[2][2], length=y_resolution)

    u_dofvals = undoBCS(ctx, u, bdata)
    u_nodevals = u_dofvals[ctx.node_to_dof]

    fs = [evaluate_function_from_node_or_cellvals(ctx, u_nodevals, Vec{2}((x,y)))
        for x in xs, y in ys]

    currentmin = Inf
    result = nothing
    
    for cl in levels(contours(xs, ys, fs, n_candidates))
        value = objective_function(cl)
        if value < currentmin
            currentmin = value
            result = cl
        end
    end
    return result, currentmin
end
# Out:
# get_minimal_levelset (generic function with 1 method)

# %%
function dynamic_cheeger_value_levelset(levelset)
    curves = lines(levelset)
    if length(curves) != 1 
        @warn "Currently only connected levelsets are allowed! Levelset: ", level(levelset)
    end
    curve = curves[1]
    return dynamic_cheeger_value(ctx,curve,x -> T(x,0),tolerance=1e-10)
end
# Out:
# dynamic_cheeger_value_levelset (generic function with 1 method)

# %%
function dynamic_cheeger_value_levelset_nonnegative(levelset)
    if level(levelset) < 0
        return Inf
    end
    curves = lines(levelset)
    if length(curves) != 1 
        @warn "Currently only connected levelsets are allowed! Levelset: $(level(levelset))"
    end
    curve = curves[1]
    return dynamic_cheeger_value(ctx,curve,x -> T(x,0),tolerance=1e-10)
end
# Out:
# dynamic_cheeger_value_levelset_nonnegative (generic function with 1 method)

# %%
best_levelset, best_value = get_minimal_levelset(
    ctx,u₀,dynamic_cheeger_value_levelset_nonnegative,n_candidates=1000,bdata=bdata)
print("Dynamic Cheeger value:\t",best_value,"\n")
print("Levelset:\t\t",level(best_levelset),"\n")
# Out:
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.00028711814276105585
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0008566286603147177
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0014261391778683241
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.001995649695421986
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0025651602129755924
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0031346707305292543
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0037041812480828606
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0042736917656365225
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.004843202283190184
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.005412712800743791
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.005982223318297453
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.006551733835851059
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.007121244353404721
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.007690754870958383
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.00826026538851199
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.008829775906065651
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.009399286423619257
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.00996879694117292
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.010538307458726581
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.011107817976280188
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.01167732849383385
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.012246839011387456
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.012816349528941118
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.013385860046494724
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.013955370564048386
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.014524881081602048
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.015094391599155654
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.015663902116709316
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.016233412634262923
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.016802923151816584
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.017372433669370246
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.017941944186923853
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.018511454704477515
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.01908096522203112
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.019650475739584783
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02021998625713839
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02078949677469205
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.021359007292245713
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02192851780979932
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02249802832735298
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.023067538844906588
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02363704936246025
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02420655988001391
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.024776070397567518
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02534558091512118
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.025915091432674786
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.026484601950228448
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.02705411246778211
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.027623622985335716
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.028193133502889378
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.028762644020442985
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.029332154537996646
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.029901665055550253
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.030471175573103915
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.031040686090657577
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03161019660821118
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.032179707125764845
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03274921764331845
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03331872816087211
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.033888238678425775
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03445774919597938
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03502725971353304
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03559677023108665
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03616628074864031
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03673579126619392
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03730530178374758
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03787481230130124
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03844432281885485
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.03901383333640851
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.039583343853962116
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04015285437151578
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04072236488906944
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.041291875406623046
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04186138592417671
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.042430896441730315
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04300040695928398
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04356991747683764
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.044139427994391245
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04470893851194491
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04527844902949851
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.045847959547052175
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04641747006460578
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04698698058215944
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.047556491099713105
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04812600161726671
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04869551213482037
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04926502265237398
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.04983453316992764
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.050404043687481304
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05097355420503491
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05154306472258857
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05211257524014218
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05268208575769584
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.053251596275249446
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05382110679280311
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05439061731035677
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05496012782791038
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05552963834546404
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.056099148863017645
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05666865938057131
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05723816989812497
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.057807680415678575
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05837719093323224
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.05894670145078584
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.059516211968339505
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06008572248589311
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.060655233003446773
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.061224743521000435
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06179425403855404
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.062363764556107704
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06293327507366131
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06350278559121497
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06407229610876863
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06464180662632224
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0652113171438759
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06578082766142951
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06635033817898317
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06691984869653683
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06748935921409044
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0680588697316441
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0686283802491977
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06919789076675137
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.06976740128430498
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07033691180185864
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0709064223194123
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0714759328369659
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07204544335451957
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07261495387207317
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07318446438962684
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0737539749071805
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0743234854247341
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07489299594228777
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07546250645984137
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07603201697739503
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07660152749494864
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0771710380125023
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07774054853005596
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07831005904760957
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07887956956516323
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.07944908008271684
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0800185906002705
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08058810111782416
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08115761163537777
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08172712215293143
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08229663267048504
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0828661431880387
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08343565370559236
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08400516422314597
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08457467474069963
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08514418525825324
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0857136957758069
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0862832062933605
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08685271681091417
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08742222732846783
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08799173784602143
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0885612483635751
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0891307588811287
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.08970026939868236
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09026977991623603
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09083929043378963
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0914088009513433
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0919783114688969
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09254782198645056
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09311733250400417
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09368684302155783
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09425635353911149
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0948258640566651
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09539537457421876
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09596488509177237
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09653439560932603
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09710390612687969
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.0976734166444333
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09824292716198696
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09881243767954057
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09938194819709423
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.09995145871464789
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1005209692322015
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10109047974975516
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10165999026730876
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10222950078486243
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10279901130241603
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1033685218199697
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10393803233752336
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10450754285507696
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10507705337263062
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10564656389018423
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10621607440773789
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10678558492529155
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10735509544284516
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10792460596039882
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10849411647795243
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.10906362699550609
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1096331375130597
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11020264803061336
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11077215854816702
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11134166906572063
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11191117958327429
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1124806901008279
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11305020061838156
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11361971113593522
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11418922165348883
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11475873217104249
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1153282426885961
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11589775320614976
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11646726372370336
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11703677424125702
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11760628475881069
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11817579527636429
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11874530579391795
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11931481631147156
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.11988432682902522
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12045383734657888
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12102334786413249
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12159285838168615
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12216236889923976
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12273187941679342
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12330138993434708
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12387090045190069
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12444041096945435
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12500992148700796
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12557943200456162
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12614894252211523
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1267184530396689
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12728796355722255
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12785747407477616
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12842698459232982
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.12899649510988342
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1295660056274371
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13013551614499075
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13070502666254435
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13127453718009802
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13184404769765162
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13241355821520528
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1329830687327589
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13355257925031255
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13412208976786621
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13469160028541982
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13526111080297348
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1358306213205271
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13640013183808075
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1369696423556344
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13753915287318802
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13810866339074168
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1386781739082953
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.13924768442584895
# └ @ Main In[24]:7
# ┌ Warning: Currently only connected levelsets are allowed! Levelset: 0.1398171949434026
# └ @ Main In[24]:7
# Dynamic Cheeger value:	2.0559744178178274
# Levelset:		0.1415257264960635

# %%
#value from paper
c = 0.1447
plot_paper = plot_u(ctx, u₀,  grid_resolution, grid_resolution, title="c=$(round(c,digits=4))", bdata=bdata,
        colorbar=colorbar, color=color, clims=(cmin,cmax), xticks=xticks, yticks=yticks,legend=false)

curve = lines(get_levelset(ctx, u₀, c, bdata=bdata))[1]
curve_moved = apply2curve(x->T(x,0),curve)

cheeger_value = dynamic_cheeger_value(ctx, curve, x->T(x,0))
print("$(cheeger_value)\t$(getLength(curve))\t$(getLength(curve_moved))\t$(getEuclideanArea(ctx,curve))\n")

Plots.plot!(coordinates(curve))
Plots.plot!(coordinates(curve_moved))


c = level(best_levelset)
plot_ours = plot_u(ctx, u₀,  grid_resolution, grid_resolution, title="c=$(round(c,digits=4))", bdata=bdata,
        colorbar=colorbar, color=color, clims=(cmin,cmax), xticks=xticks, yticks=yticks,legend=false)

curve = lines(get_levelset(ctx, u₀, c, bdata=bdata))[1]
curve = closeCurve(ctx,curve)
curve_moved = apply2curve(x->T(x,0),curve)

cheeger_value = dynamic_cheeger_value(ctx, curve, x->T(x,0))
print("$(cheeger_value)\t$(getLength(curve))\t$(getLength(curve_moved))\t$(getEuclideanArea(ctx,curve))\n")

Plots.plot!(coordinates(curve))
Plots.plot!(coordinates(curve_moved))


Plots.plot(plot_paper, plot_ours, fmt=:png,dpi=200)
# Out:
# 2.0752408818521237	13.143616261027937	24.824687523477838	9.147926902495191
# 2.0559744178178274	13.606776185293562	25.51767114269423	9.514818615669778

# %%
X = Tuple{Float64,Float64}[]
for i in 1:50
    Random.seed!(i)
    x = 2π .* (rand(), rand())
    for i in 1:500
        x = T(x,0)
        push!(X,(x[1],x[2]))
    end
end

fig = scatter(X, markersize=1,legend=:none)
Plots.plot!(coordinates(curve),fmt=:png)
