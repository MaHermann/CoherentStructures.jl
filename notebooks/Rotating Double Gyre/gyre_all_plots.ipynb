# %%
using DelimitedFiles
using Plots

# %%
dir_name = "double_gyre_t_0.6"
vals0100 = readdlm("D:/MA_VALUES/"*dir_name*"/100_0.2.csv", ',', Float64, '\n')
vals0100qo2 = readdlm("D:/MA_VALUES/"*dir_name*"/100_0.2_qo2.csv", ',', Float64, '\n')
vals0300 = readdlm("D:/MA_VALUES/"*dir_name*"/300_0.2.csv", ',', Float64, '\n')
vals0500 = readdlm("D:/MA_VALUES/"*dir_name*"/500_0.2.csv", ',', Float64, '\n')
vals1000 = readdlm("D:/MA_VALUES/"*dir_name*"/1000_0.2.csv", ',', Float64, '\n')
lr       = readdlm("D:/MA_VALUES/"*dir_name*"/lr.csv", ',', Float64, '\n')
range0100 = 0.2
range0100qo2 = 0.2
range0300 = 0.2
range0500 = 0.2
range1000 = 0.2
#linear_responses = readdlm("D:/MA_VALUES/"*dir_name*"/1000_0.2.csv", ',', Float64, '\n');
nothing

# %%
num = ["First","Second","Third","Fourth","Fifth","Sixth"]
res = [100 300 500 1000]'
nothing

# %%
system = "Rotating Double Gyre, t₀=0.6"
ev = 2
ϵ  = 0.1
γ  = 0.01
nothing

# %%
idx_0_0100 = Int(round((size(vals0100)[1]+1)/2))
idx_0_0100qo2 = Int(round((size(vals0100qo2)[1]+1)/2))
idx_0_0300 = Int(round((size(vals0300)[1]+1)/2))
idx_0_0500 = Int(round((size(vals0500)[1]+1)/2))
idx_0_1000 = Int(round((size(vals1000)[1]+1)/2))
off_ϵ_0100 = Int(round(((size(vals0100)[1]-1)/2) * (ϵ/range0100)))
off_ϵ_0100qo2 = Int(round(((size(vals0100qo2)[1]-1)/2) * (ϵ/range0100qo2)))
off_ϵ_0300 = Int(round(((size(vals0300)[1]-1)/2) * (ϵ/range0300)))
off_ϵ_0500 = Int(round(((size(vals0500)[1]-1)/2) * (ϵ/range0500)))
off_ϵ_1000 = Int(round(((size(vals1000)[1]-1)/2) * (ϵ/range1000)))
off_γ_0100 = Int(round(((size(vals0100)[1]-1)/2) * (γ/range0100)))
off_γ_0100qo2 = Int(round(((size(vals0100qo2)[1]-1)/2) * (γ/range0100qo2)))
off_γ_0300 = Int(round(((size(vals0300)[1]-1)/2) * (γ/range0300)))
off_γ_0500 = Int(round(((size(vals0500)[1]-1)/2) * (γ/range0500)))
off_γ_1000 = Int(round(((size(vals1000)[1]-1)/2) * (γ/range1000)))
nothing

# %%
#sanity checks
print(-γ," 0.0 ",γ,"\n")
print(vals0100[idx_0_0100 - off_γ_0100,1]," ",vals0100[idx_0_0100,1]," ",vals0100[idx_0_0100 + off_γ_0100,1],"\n")
print(vals0100qo2[idx_0_0100qo2 - off_γ_0100qo2,1]," ",vals0100qo2[idx_0_0100qo2,1]," ",vals0100qo2[idx_0_0100qo2 + off_γ_0100qo2,1],"\n")
print(vals0300[idx_0_0300 - off_γ_0300,1]," ",vals0300[idx_0_0300,1]," ",vals0300[idx_0_0300 + off_γ_0300,1],"\n")
print(vals0500[idx_0_0500 - off_γ_0500,1]," ",vals0500[idx_0_0500,1]," ",vals0500[idx_0_0500 + off_γ_0500,1],"\n")
print(vals1000[idx_0_1000 - off_γ_1000,1]," ",vals1000[idx_0_1000,1]," ",vals1000[idx_0_1000 + off_γ_1000,1],"\n")
print(-ϵ," 0.0 ",ϵ,"\n")
print(vals0100[idx_0_0100 - off_ϵ_0100,1]," ",vals0100[idx_0_0100,1]," ",vals0100[idx_0_0100 + off_ϵ_0100,1],"\n")
print(vals0100qo2[idx_0_0100qo2 - off_ϵ_0100qo2,1]," ",vals0100qo2[idx_0_0100qo2,1]," ",vals0100qo2[idx_0_0100qo2 + off_ϵ_0100qo2,1],"\n")
print(vals0300[idx_0_0300 - off_ϵ_0300,1]," ",vals0300[idx_0_0300,1]," ",vals0300[idx_0_0300 + off_ϵ_0300,1],"\n")
print(vals0500[idx_0_0500 - off_ϵ_0500,1]," ",vals0500[idx_0_0500,1]," ",vals0500[idx_0_0500 + off_ϵ_0500,1],"\n")
print(vals1000[idx_0_1000 - off_ϵ_1000,1]," ",vals1000[idx_0_1000,1]," ",vals1000[idx_0_1000 + off_ϵ_1000,1],"\n")
# Out:
# -0.01 0.0 0.01
# -0.01 0.0 0.01
# -0.01 0.0 0.01
# -0.01 0.0 0.01
# -0.01 0.0 0.01
# -0.01 0.0 0.01
# -0.1 0.0 0.1
# -0.1 0.0 0.1
# -0.1 0.0 0.1
# -0.1 0.0 0.1
# -0.1 0.0 0.1
# -0.1 0.0 0.1

# %%
lr
# Out:
# 4×6 Array{Float64,2}:
#   100.0  0.0   55.9524  0.0  0.0  -217.684
#   300.0  0.0  -64.9591  0.0  0.0  -252.341
#   500.0  0.0  -59.4253  0.0  0.0  -259.336
#  1000.0  0.0  -55.371   0.0  0.0  -267.983

# %%
conv1 = Plots.plot(res,[vals0100[idx_0_0100 - off_γ_0100,ev+1] 
                          vals0300[idx_0_0300 - off_γ_0300,ev+1]
                          vals0500[idx_0_0500 - off_γ_0500,ev+1]
                          vals1000[idx_0_1000 - off_γ_1000,ev+1]],
                label="ϵ=-"*string(γ),marker=:dot, legend=(0.7,0.8))
Plots.plot!(res,[vals0100[idx_0_0100 - off_ϵ_0100,ev+1] 
                   vals0300[idx_0_0300 - off_ϵ_0300,ev+1]
                   vals0500[idx_0_0500 - off_ϵ_0500,ev+1]
                   vals1000[idx_0_1000 - off_ϵ_1000,ev+1]],
                label="ϵ=-"*string(ϵ),marker=:dot)
Plots.plot!(res,[vals0100[idx_0_0100,ev+1] 
                   vals0300[idx_0_0300,ev+1]
                   vals0500[idx_0_0500,ev+1]
                   vals1000[idx_0_1000,ev+1]],
                label="ϵ=0",marker=:dot,linewidth=2)
Plots.plot!(res,[vals0100[idx_0_0100 + off_γ_0100,ev+1] 
                   vals0300[idx_0_0300 + off_γ_0300,ev+1] 
                   vals0500[idx_0_0500 + off_γ_0500,ev+1] 
                   vals1000[idx_0_1000 + off_γ_1000,ev+1]],
                label="ϵ=+"*string(γ),marker=:dot)
Plots.plot!(res,[vals0100[idx_0_0100 + off_ϵ_0100,ev+1] 
                   vals0300[idx_0_0300 + off_ϵ_0300,ev+1]
                   vals0500[idx_0_0500 + off_ϵ_0500,ev+1] 
                   vals1000[idx_0_1000 + off_ϵ_1000,ev+1]],
                label="ϵ=-"*string(ϵ),marker=:dot)

# %%
param = Plots.plot(vals0100[:,1],vals0100[:,ev+1],label="100",legend=(0.3,0.3))
Plots.plot!(vals0300[:,1],vals0300[:,ev+1],label="300")
Plots.plot!(vals0500[:,1],vals0500[:,ev+1],label="500")
Plots.plot!(vals1000[:,1],vals1000[:,ev+1],label="1000")
Plots.plot!(vals0100qo2[:,1],vals0100qo2[:,ev+1],label="100, qo=2",color=:black)
#Plots.plot!([ϵ],[vals0100[idx_0_0100 + off_ϵ_0100,ev+1]],marker=:dot)

# %%
Plots.plot(tangent_plot0100qo2,dpi=300,title="Second Eigenvalue, Gridsize 100,\nQuadrature Order 2",fmt=:png,titlefontsize=20,legendfontsize=10,legend=false)

# %%
linear_respones = Plots.plot(res,
        [(vals0100[idx_0_0100,ev+1] - vals0100[idx_0_0100 - off_γ_0100,ev+1])/γ
         (vals0300[idx_0_0300,ev+1] - vals0300[idx_0_0300 - off_γ_0300,ev+1])/γ
          (vals0500[idx_0_0500,ev+1] - vals0500[idx_0_0500 - off_γ_0500,ev+1])/γ
         (vals1000[idx_0_1000,ev+1] - vals1000[idx_0_1000 - off_γ_1000,ev+1])/γ],
      label="FD left, ϵ="*string(γ),marker=:vline,legend=(0.8,0.8))
Plots.plot!(res,
        [(vals0100[idx_0_0100,ev+1] - vals0100[idx_0_0100 - off_ϵ_0100,ev+1])/ϵ
         (vals0300[idx_0_0300,ev+1] - vals0300[idx_0_0300 - off_ϵ_0300,ev+1])/ϵ
         (vals0500[idx_0_0500,ev+1] - vals0500[idx_0_0500 - off_ϵ_0500,ev+1])/ϵ
         (vals1000[idx_0_1000,ev+1] - vals1000[idx_0_1000 - off_ϵ_1000,ev+1])/ϵ],
      label="FD left, ϵ="*string(ϵ),marker=:vline)
Plots.plot!(res,
        [(vals0100[idx_0_0100 + off_γ_0100,ev+1] - vals0100[idx_0_0100 - off_γ_0100,ev+1])/(2γ)
         (vals0300[idx_0_0300 + off_γ_0300,ev+1] - vals0300[idx_0_0300 - off_γ_0300,ev+1])/(2γ)
         (vals0500[idx_0_0500 + off_γ_0500,ev+1] - vals0500[idx_0_0500 - off_γ_0500,ev+1])/(2γ)
         (vals1000[idx_0_1000 + off_γ_1000,ev+1] - vals1000[idx_0_1000 - off_γ_1000,ev+1])/(2γ)],
      label="FD both, ϵ="*string(γ),marker=:vline)
Plots.plot!(res,
        [(vals0100[idx_0_0100 + off_ϵ_0100,ev+1] - vals0100[idx_0_0100 - off_ϵ_0100,ev+1])/(2ϵ)
         (vals0300[idx_0_0300 + off_ϵ_0300,ev+1] - vals0300[idx_0_0300 - off_ϵ_0300,ev+1])/(2ϵ)
         (vals0500[idx_0_0500 + off_ϵ_0500,ev+1] - vals0500[idx_0_0500 - off_ϵ_0500,ev+1])/(2ϵ)
         (vals1000[idx_0_1000 + off_ϵ_1000,ev+1] - vals1000[idx_0_1000 - off_ϵ_1000,ev+1])/(2ϵ)],
      label="FD both, ϵ="*string(ϵ),marker=:vline)
Plots.plot!(res,
        [(vals0100[idx_0_0100 + off_γ_0100,ev+1] - vals0100[idx_0_0100,ev+1])/γ
         (vals0300[idx_0_0300 + off_γ_0300,ev+1] - vals0300[idx_0_0300,ev+1])/γ
         (vals0500[idx_0_0500 + off_γ_0500,ev+1] - vals0500[idx_0_0500,ev+1])/γ
         (vals1000[idx_0_1000 + off_γ_1000,ev+1] - vals1000[idx_0_1000,ev+1])/γ],
      label="FD right, ϵ="*string(γ),marker=:vline)
Plots.plot!(res,
        [(vals0100[idx_0_0100 + off_ϵ_0100,ev+1] - vals0100[idx_0_0100,ev+1])/ϵ
         (vals0300[idx_0_0300 + off_ϵ_0300,ev+1] - vals0300[idx_0_0300,ev+1])/ϵ
         (vals0500[idx_0_0500 + off_ϵ_0500,ev+1] - vals0500[idx_0_0500,ev+1])/ϵ
         (vals1000[idx_0_1000 + off_ϵ_1000,ev+1] - vals1000[idx_0_1000,ev+1])/ϵ],
      label="FD right, ϵ="*string(ϵ),marker=:vline)
Plots.plot!(lr[:,1],lr[:,ev+1],marker=:dot,linewidth=2,color=:black,label="lr")

# %%
fd0100_ϵ = (vals0100[idx_0_0100 + off_ϵ_0100,ev+1] - vals0100[idx_0_0100 - off_ϵ_0100,ev+1])/(2ϵ)
fd0300_ϵ =(vals0300[idx_0_0300 + off_ϵ_0300,ev+1] - vals0300[idx_0_0300 - off_ϵ_0300,ev+1])/(2ϵ)
fd0500_ϵ =(vals0500[idx_0_0500 + off_ϵ_0500,ev+1] - vals0500[idx_0_0500 - off_ϵ_0500,ev+1])/(2ϵ)
fd1000_ϵ =(vals1000[idx_0_1000 + off_ϵ_1000,ev+1] - vals1000[idx_0_1000 - off_ϵ_1000,ev+1])/(2ϵ)

fd0100_γ = (vals0100[idx_0_0100 + off_γ_0100,ev+1] - vals0100[idx_0_0100 - off_γ_0100,ev+1])/(2γ)
fd0300_γ = (vals0300[idx_0_0300 + off_γ_0300,ev+1] - vals0300[idx_0_0300 - off_γ_0300,ev+1])/(2γ)
fd0500_γ = (vals0500[idx_0_0500 + off_γ_0500,ev+1] - vals0500[idx_0_0500 - off_γ_0500,ev+1])/(2γ)
fd1000_γ = (vals1000[idx_0_1000 + off_γ_1000,ev+1] - vals1000[idx_0_1000 - off_γ_1000,ev+1])/(2γ)


offset_fd0100_ϵ = fd0100_ϵ * (vals0100[idx_0_0100,1] - vals0100[1,1])
tangent_fd0100_ϵ = [vals0100[idx_0_0100,ev+1]-offset_fd0100_ϵ 
                    vals0100[idx_0_0100,ev+1] 
                    vals0100[idx_0_0100,ev+1]+offset_fd0100_ϵ]

offset_fd0100_γ = fd0100_γ * (vals0100[idx_0_0100,1] - vals0100[1,1])
tangent_fd0100_γ = [vals0100[idx_0_0100,ev+1]-offset_fd0100_γ 
                    vals0100[idx_0_0100,ev+1] 
                    vals0100[idx_0_0100,ev+1]+offset_fd0100_γ]

offset_lr0100 = lr[1,ev+1] * (vals0100[idx_0_0100,1] - vals0100[1,1])
tangent_lr0100 = [vals0100[idx_0_0100,ev+1]-offset_lr0100 
                    vals0100[idx_0_0100,ev+1] 
                    vals0100[idx_0_0100,ev+1]+offset_lr0100]

offset_fd0300_ϵ = fd0300_ϵ * (vals0300[idx_0_0300,1] - vals0300[1,1])
tangent_fd0300_ϵ = [vals0300[idx_0_0300,ev+1]-offset_fd0300_ϵ 
                    vals0300[idx_0_0300,ev+1] 
                    vals0300[idx_0_0300,ev+1]+offset_fd0300_ϵ]

offset_fd0300_γ = fd0300_γ * (vals0300[idx_0_0300,1] - vals0300[1,1])
tangent_fd0300_γ = [vals0300[idx_0_0300,ev+1]-offset_fd0300_γ 
                    vals0300[idx_0_0300,ev+1] 
                    vals0300[idx_0_0300,ev+1]+offset_fd0300_γ]

offset_lr0300 = lr[2,ev+1] * (vals0300[idx_0_0300,1] - vals0300[1,1])
tangent_lr0300 = [vals0300[idx_0_0300,ev+1]-offset_lr0300 
                    vals0300[idx_0_0300,ev+1] 
                    vals0300[idx_0_0300,ev+1]+offset_lr0300]

offset_fd0500_ϵ = fd0500_ϵ * (vals0500[idx_0_0500,1] - vals0500[1,1])
tangent_fd0500_ϵ = [vals0500[idx_0_0500,ev+1]-offset_fd0500_ϵ 
                    vals0500[idx_0_0500,ev+1] 
                    vals0500[idx_0_0500,ev+1]+offset_fd0500_ϵ]

offset_fd0500_γ = fd0500_γ * (vals0500[idx_0_0500,1] - vals0500[1,1])
tangent_fd0500_γ = [vals0500[idx_0_0500,ev+1]-offset_fd0500_γ 
                    vals0500[idx_0_0500,ev+1] 
                    vals0500[idx_0_0500,ev+1]+offset_fd0500_γ]

offset_lr0500 = lr[3,ev+1] * (vals0500[idx_0_0500,1] - vals0500[1,1])
tangent_lr0500 = [vals0500[idx_0_0500,ev+1]-offset_lr0500 
                    vals0500[idx_0_0500,ev+1] 
                    vals0500[idx_0_0500,ev+1]+offset_lr0500]

offset_fd1000_ϵ = fd1000_ϵ * (vals1000[idx_0_1000,1] - vals1000[1,1])
tangent_fd1000_ϵ = [vals1000[idx_0_1000,ev+1]-offset_fd1000_ϵ 
                    vals1000[idx_0_1000,ev+1] 
                    vals1000[idx_0_1000,ev+1]+offset_fd1000_ϵ]

offset_fd1000_γ = fd1000_γ * (vals1000[idx_0_1000,1] - vals1000[1,1])
tangent_fd1000_γ = [vals1000[idx_0_1000,ev+1]-offset_fd1000_γ 
                    vals1000[idx_0_1000,ev+1] 
                    vals1000[idx_0_1000,ev+1]+offset_fd1000_γ]
            
offset_lr1000 = lr[4,ev+1] * (vals1000[idx_0_1000,1] - vals1000[1,1])
tangent_lr1000 = [vals1000[idx_0_1000,ev+1]-offset_lr1000 
                    vals1000[idx_0_1000,ev+1] 
                    vals1000[idx_0_1000,ev+1]+offset_lr1000]

tangent_plot0100 = Plots.plot(vals0100[:,1],vals0100[:,ev+1], color=1, legend=false, linewidth=2)
Plots.plot!([vals0100[1,1] vals0100[idx_0_0100,1] vals0100[end,1]]', tangent_fd0100_ϵ, color=:black, linestyle=:dot)
Plots.plot!([vals0100[idx_0_0100 - off_ϵ_0100,1]], [vals0100[idx_0_0100 - off_ϵ_0100,ev+1]],color=1,marker=:dot)
Plots.plot!([vals0100[idx_0_0100 + off_ϵ_0100,1]], [vals0100[idx_0_0100 + off_ϵ_0100,ev+1]],color=1,marker=:dot)
Plots.plot!([vals0100[1,1] vals0100[idx_0_0100,1] vals0100[end,1]]', tangent_fd0100_γ, color=:black, linestyle=:dot)
Plots.plot!([vals0100[idx_0_0100 - off_γ_0100,1]], [vals0100[idx_0_0100 - off_γ_0100,ev+1]],color=1,marker=:dot)
Plots.plot!([vals0100[idx_0_0100 + off_γ_0100,1]], [vals0100[idx_0_0100 + off_γ_0100,ev+1]],color=1,marker=:dot)
Plots.plot!([vals0100[1,1] vals0100[idx_0_0100,1] vals0100[end,1]]', tangent_lr0100, color=:black)

tangent_plot0300 = Plots.plot(vals0300[:,1],vals0300[:,ev+1], color=2, legend=false, linewidth=2)
Plots.plot!([vals0300[1,1] vals0100[idx_0_0300,1] vals0300[end,1]]', tangent_fd0300_ϵ, color=:black, linestyle=:dot)
Plots.plot!([vals0300[idx_0_0300 - off_ϵ_0300,1]], [vals0300[idx_0_0300 - off_ϵ_0300,ev+1]],color=2,marker=:dot)
Plots.plot!([vals0300[idx_0_0300 + off_ϵ_0300,1]], [vals0300[idx_0_0300 + off_ϵ_0300,ev+1]],color=21,marker=:dot)
Plots.plot!([vals0300[1,1] vals0300[idx_0_0300,1] vals0300[end,1]]', tangent_fd0300_γ, color=:black, linestyle=:dot)
Plots.plot!([vals0300[idx_0_0300 - off_γ_0300,1]], [vals0300[idx_0_0300 - off_γ_0300,ev+1]],color=2,marker=:dot)
Plots.plot!([vals0300[idx_0_0300 + off_γ_0300,1]], [vals0300[idx_0_0300 + off_γ_0300,ev+1]],color=2,marker=:dot)
Plots.plot!([vals0300[1,1] vals0100[idx_0_0300,1] vals0300[end,1]]', tangent_lr0300, color=:black)

tangent_plot0500 = Plots.plot(vals0500[:,1],vals0500[:,ev+1], color=3, legend=false, linewidth=2)
Plots.plot!([vals0500[1,1] vals0500[idx_0_0500,1] vals0500[end,1]]', tangent_fd0500_ϵ, color=:black, linestyle=:dot)
Plots.plot!([vals0500[idx_0_0500 - off_ϵ_0500,1]], [vals0500[idx_0_0500 - off_ϵ_0500,ev+1]],color=3,marker=:dot)
Plots.plot!([vals0500[idx_0_0500 + off_ϵ_0500,1]], [vals0500[idx_0_0500 + off_ϵ_0500,ev+1]],color=3,marker=:dot)
Plots.plot!([vals0500[1,1] vals0500[idx_0_0500,1] vals0500[end,1]]', tangent_fd0500_γ, color=:black, linestyle=:dot)
Plots.plot!([vals0500[idx_0_0500 - off_γ_0500,1]], [vals0500[idx_0_0500 - off_γ_0500,ev+1]],color=3,marker=:dot)
Plots.plot!([vals0500[idx_0_0500 + off_γ_0500,1]], [vals0500[idx_0_0500 + off_γ_0500,ev+1]],color=3,marker=:dot)
Plots.plot!([vals0500[1,1] vals0500[idx_0_0500,1] vals0500[end,1]]', tangent_lr0500, color=:black)

tangent_plot1000 = Plots.plot(vals1000[:,1],vals1000[:,ev+1], color=4, legend=false, linewidth=2)
Plots.plot!([vals1000[1,1] vals1000[idx_0_1000,1] vals1000[end,1]]', tangent_fd1000_ϵ, color=:black, linestyle=:dot)
Plots.plot!([vals1000[idx_0_1000 - off_ϵ_1000,1]], [vals1000[idx_0_1000 - off_ϵ_1000,ev+1]],color=4,marker=:dot)
Plots.plot!([vals1000[idx_0_1000 + off_ϵ_1000,1]], [vals1000[idx_0_1000 + off_ϵ_1000,ev+1]],color=4,marker=:dot)
Plots.plot!([vals1000[1,1] vals1000[idx_0_1000,1] vals1000[end,1]]', tangent_fd1000_γ, color=:black, linestyle=:dot)
Plots.plot!([vals1000[idx_0_1000 - off_γ_1000,1]], [vals1000[idx_0_1000 - off_γ_1000,ev+1]],color=4,marker=:dot)
Plots.plot!([vals1000[idx_0_1000 + off_γ_1000,1]], [vals1000[idx_0_1000 + off_γ_1000,ev+1]],color=4,marker=:dot)
Plots.plot!([vals1000[1,1] vals1000[idx_0_1000,1] vals1000[end,1]]', tangent_lr1000, color=:black)


Plots.plot(tangent_plot0100,tangent_plot0300,tangent_plot0500,tangent_plot1000)

# %%
lr_0100qo2 = -56.43099628178683

offset_lr0100qo2 = lr_0100qo2 * (vals0100qo2[idx_0_0100qo2,1] - vals0100qo2[1,1])
tangent_lr0100qo2 = [vals0100qo2[idx_0_0100qo2,ev+1] - offset_lr0100qo2
                     vals0100qo2[idx_0_0100qo2,ev+1] 
                     vals0100qo2[idx_0_0100qo2,ev+1] + offset_lr0100qo2]

tangent_plot0100qo2 = Plots.plot(vals0100qo2[:,1],vals0100qo2[:,ev+1], color=4, legend=false, linewidth=2)
Plots.plot!([vals0100qo2[1,1] vals0100qo2[idx_0_0100qo2,1] vals0100qo2[end,1]]', tangent_lr0100qo2, color=:black)

# %%
Plots.plot(conv1,linear_respones,param,tangent_plot0100,tangent_plot0300,tangent_plot0500,tangent_plot1000,
       dpi=300,fmt=:png,legendfontsize=4,fontsize=4,titlefontsize=4,title="")
    #title=system*"\n"*num[ev]*" Eigenvalue")

# %% [markdown]
# #plotting a new mesh
# #ctx_plot, _ = regularTriangularGrid((10, 10), LL, UR, quadrature_order = quadrature_order)
# #flow_map_t(j) = Vec{2}(round.(T(ctx_plot.grid.nodes[j].x, 0), digits=5))
# #new_ctx_plot,_,_ = Main.CoherentStructures.adaptiveTOFutureGrid(ctx_plot,flow_map_t,flow_map_mode=1)
#
# #original_grid = Main.CoherentStructures.plot_grid(ctx_plot)
# #adapted_grid = Main.CoherentStructures.plot_grid(new_ctx_plot)
# #Plots.plot(original_grid,adapted_grid)
#
#
#
# ctx_plot, _ = regularTriangularGrid((15, 15), LL, UR, quadrature_order = quadrature_order)
# flow_map_t(j) = Vec{2}(T(ctx_plot.grid.nodes[j].x,0))
# new_ctx_plot,_,_ = Main.CoherentStructures.adaptiveTOFutureGrid(ctx_plot,flow_map_t,flow_map_mode=1)
#
# original_grid = Main.CoherentStructures.plot_grid(ctx_plot)
# adapted_grid = Main.CoherentStructures.plot_grid(new_ctx_plot)
# Plots.plot(original_grid,adapted_grid,fmt=:png)
